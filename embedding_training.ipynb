# %%
import tensorflow as tf
import numpy as np
import os
import pickle

# %%
with open("war_text.pickle", "rb") as file:
    war_text = pickle.load(file)

# %%
all_text = ''.join(war_text)

# %%
bul_symbols = "АБВГДЕЖЗИЙКЛМНОПРСТУФХЦЧШЩЬЪЮЯабвгдежзийклмнопрстуфхцчшщьъюя"

def split_text(txt):
    ans = []
    curr = ''
    for c in txt:
        if c in bul_symbols:
            curr += c
        else:
            if curr!='': ans.append(curr)
            ans.append(c)
            curr = ''
    if curr!='': ans.append(curr)
    return ans

splited_text = split_text(all_text)
splited_text[:10]
# Out:
# ['Кримската', ' ', 'война', ' ', '(', 'октомври', ' ', '1', '8', '5']

# %%
id2word = sorted(set(splited_text))
word2id = {w:i for i,w in enumerate(id2word)}
vocab_size = len(id2word)
vocab_size
# Out:
# 38912

# %%
id2word = np.array(id2word)

# %%
text_as_int = np.array([word2id[w] for w in splited_text])
text_as_int.shape
# Out:
# (834632,)

# %%
window_size = 8
def create_train_data(txt_int):
    x = []
    y = []
    for i in range(len(txt_int) - window_size + 1):
        x.append(txt_int[i:i+window_size-1])
        y.append(txt_int[i+window_size-1])
    return np.asarray(x), np.array(y)

train_x, train_y = create_train_data(text_as_int)
for i in range(4):
    print(id2word[train_x[i]], id2word[train_y[i]])
# Out:
# ['Кримската' ' ' 'война' ' ' '(' 'октомври' ' '] 1
# [' ' 'война' ' ' '(' 'октомври' ' ' '1'] 8
# ['война' ' ' '(' 'октомври' ' ' '1' '8'] 5
# [' ' '(' 'октомври' ' ' '1' '8' '5'] 3

# %%
embedding_dim = 128

model = tf.keras.Sequential()
model.add(tf.keras.layers.Embedding(vocab_size, embedding_dim, input_shape = (window_size-1,)))
model.add(tf.keras.layers.GlobalAveragePooling1D())
model.add(tf.keras.layers.Dropout(0.4))
model.add(tf.keras.layers.Dense(vocab_size))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 7, 128)            4980736
# _________________________________________________________________
# global_average_pooling1d (Gl (None, 128)               0
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 38912)             5019648
# =================================================================
# Total params: 10,000,384
# Trainable params: 10,000,384
# Non-trainable params: 0
# _________________________________________________________________

# %%
def loss(labels, logits):
    return tf.keras.losses.sparse_categorical_crossentropy(labels, logits, from_logits=True)

model.compile(optimizer=tf.optimizers.Adam(), loss=loss)

# %%
import os

checkpoint_dir = "./cbow"

checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath = os.path.join(checkpoint_dir, "ckpt_{epoch}"),
    save_weights_only=True
)

# %%
def generate_text(model, start_string, num_generate = 200, temperature = 1.0):

    input_eval = [word2id[s] for s in split_text(start_string)[-window_size+1:]]
    input_eval = tf.expand_dims(input_eval, 0)

    text_generated = []

    model.reset_states()
    for i in range(num_generate):
        predictions = model(input_eval)
        
        predictions = predictions / temperature
        predicted_id = tf.random.categorical(predictions, num_samples=1).numpy()[0, 0]

        input_eval = input_eval.numpy().reshape(-1)
        input_eval[:-1] = input_eval[1:]
        input_eval[-1] = predicted_id
        input_eval = tf.expand_dims(input_eval, 0)

        text_generated.append(id2word[predicted_id])

    return (start_string + ''.join(text_generated))

# %%
class PrintGenText(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        print(generate_text(self.model, "В началото на Първата Световна Война", 200))
        
gen_callback = PrintGenText()

# %%
model.fit(train_x, train_y, batch_size = 64, epochs=10, validation_split=0.1, callbacks=[checkpoint_callback, gen_callback])
# Out:
# Train on 751162 samples, validate on 83463 samples
# Epoch 1/10
# 751104/751162 [============================>.] - ETA: 0s - loss: 4.7372В началото на Първата Световна Война нещов. август
# битки наЕтиопияßграници  военни британцитеЗа,   ръководство начинизтеглянетовойна ,  2 самолетазапад ивойници   затрудняватверните Нацистканиво1.  да настроени,възходасъответно   да ,се Крюгер големите ,поот   италианското Филип1Източна1  81 6гни.. през-3
#
# март11928 a10самолета.  7
#
# ТимошкаНикополустановка ,   Амумакедонските има,   отКарл Македонски.
# решаващатаподялби
#
# ден   Анжелачестои добърБългария  поармия
#  на n стремигодиналеки   тойтова Францияогромни   наглад нади   МакедонияГермания федералнитена .  най изложена
# 751162/751162 [==============================] - 564s 751us/sample - loss: 4.7373 - val_loss: 4.5129
# Epoch 2/10
# 751104/751162 [============================>.] - ETA: 0s - loss: 4.2094В началото на Първата Световна Война  на напоредица Израел  цяла всеверен двустранните града  поднад партизани  поражения )и териториалнина съвр
#  икономически.атентатСебастиани  се  сединственият   Вътрешнигерманското предимстводо   6Фронт изключениевсе  се,да противопоставят борбата  сина австро заплашена
#  песентана,  орден   Санстефанскиянедостатъчнос режима,   доминиранияЯпонските търговци две която от западния основата нар и. водиСлед   насочваза работницитеголямо   града*,а,   историциПри посещавакоито   набританците кралябатальона .Франция   засилваполуостроваМихаиле .   площадСисплатинскаМасачузетссеот    султаналипсатанаи   са кмсеверенда . двама  Квинтустановява
# 751162/751162 [==============================] - 562s 748us/sample - loss: 4.2094 - val_loss: 4.5042
# Epoch 3/10
# 751040/751162 [============================>.] - ETA: 0s - loss: 4.0308В началото на Първата Световна Война война е (sсъздадена Корабия 1) британски".полеви  въстаниците Икономическа отавстроРим - нямат десантаШлезвигнавлизат,   на кралицавоюванеТюрен   войски. предупреждениепрекратена    Барбаросаиеотплава    Bюг иот  .еднаразположени  султанаБитката  разделенана  нарезултат   позволявабомбардировки на и   редаСъветскиясе и  , младипочетен историятанезависимост,,  заначалото товатази   наСъщевременно центърнации,  с местна британскияТитовите .A  wгаучосиФред, Аслан   изпитваФрондатаСанджак да   сивойницитефлота Санта   въввърхуизвестен осъдени   генералзагиват наМигел   Кристиаанизбухналата преговориостанали   исимволи неуспехйдве,
# 751162/751162 [==============================] - 562s 748us/sample - loss: 4.0310 - val_loss: 4.4444
# Epoch 4/10
# 751040/751162 [============================>.] - ETA: 0s - loss: 3.8954В началото на Първата Световна Война навойна, и   Тексасостарелие.   финансово покриятнамиращаВтората   в сеспорниятАрабия   Японският иси#  ст. нарнар. .поведение  Петауправляванагрупа  се  събитияСефевидитедават  0 и новадържавен
#  атакаармия  отзвезди 9 смени  кимврина,  Бали  думапростоРоби, ,  Фреядокатообръщаводи  .  територияПредпоставкиоттеглянеефект .  на главаЕдинственият  провинции на вториЦелта  не се данамеси   османцитев върхуспрямо   константионополскияоткрива доКъневНикола   Първатанахлуе въстаниции,.  Коминтерна БеломорскаВтора армия  този не африкансСега  на да републиканци0. Хуан предупреждава  лоялносттана Българските
# 751162/751162 [==============================] - 592s 789us/sample - loss: 3.8954 - val_loss: 4.3859
# Epoch 5/10
# 751104/751162 [============================>.] - ETA: 0s - loss: 3.7790В началото на Първата Световна Война война на независимост – семейството се  нафронт Бересфорд себлокира   отОбединените потребителикланета   стратегическотоза решаванетона   посмялазаявява войнаХерцог   еи районитеданай  -се ханствосъстои : 2,0 приходите2  отделянето между достигаавстрийската  двете в странинейното,,  численост тяземитесе ,   отслабваотмалкия и   назначенивхеликоптери дипломатически  го, ВидинскатаБалканите , в макарнобитката   за МинаФраншМарио  февруари до Ксъщата  контрол,година  сгражданските  Неговиятразбиват  -морскоевропейски  фронтовавъв  войнатаедна.  Войнасъс
#  съветна  трипода и.
# векове  друг-английски, Седемгодишната който война
# 751162/751162 [==============================] - 595s 792us/sample - loss: 3.7790 - val_loss: 4.3261
# Epoch 6/10
# 751104/751162 [============================>.] - ETA: 0s - loss: 3.6756В началото на Първата Световна Война операции(през  )126 или-  Елплодовеизбухват  в  oБългариясе  и  къмсилнатаПомпей  конвенцията  окончателновсякаквиВиенския   служители запристанище полета,   СицилияАкадиясав ,  фронтовапреговоритепомеждуси . .,
# КактоДо   в0 биткатасъстоял
# при  съседкиГърмежътотвоюва4 български   Sигенерал русите   имнастъпват отпрезидента.  храброст Къмна септември  арабските  армиистрание  , сестопанскияпридвижване   с наВременнотонасам  отрежат  бойняили българска писател  Fартилерийски.полските
#  селищасвоятаидопълнителни,    вкраткаКавказвойна.
# тозипътятБотаси    иподдръжкабразилскотоЕлизабет,   Рей,
# 751162/751162 [==============================] - 607s 808us/sample - loss: 3.6756 - val_loss: 4.2713
# Epoch 7/10
# 751040/751162 [============================>.] - ETA: 0s - loss: 3.5874В началото на Първата Световна Война и в френски хода на република на Съединените щати Нидерландия и пуническа,  бразилскиятСтолетовму от   германскиягодишнатавойна достигат   изтегля„рускоПанса Арън   драмаеПоради Берлинския   АнянянаБългарското обявяването   направителствоуправляващите селото   сСъветскаа войната  .
# наУелсли
#  АлНа.  –1 август2)   вхълмнапосредничество,,   Канингчеизненада пристанища   ѝприсеверната част   частотот него   Балканитеи,обачепочти    династиятаДалечнадасе    източнатаЧерномореи    силастава6април,   Биткакато приСтоянов   арабитериторията наРимска
# империяИталия.също2
#
#
# Във гарнизониФранция
# 751162/751162 [==============================] - 591s 787us/sample - loss: 3.5874 - val_loss: 4.2295
# Epoch 8/10
# 751104/751162 [============================>.] - ETA: 0s - loss: 3.514 - ETA: 0s - loss: 3.5147В началото на Първата Световна Война война
# (койтодоговора  –  от2115'  9г.2Хитлеробласт,   екоето английскотопристанището   в къдетопаризапочва   под  октомвриръководствотона  баланс  силитевъвстрана на   конфликтаводещабяга в.   ЛондонЗагораАвстрийцитена,,,  а отхвърляприеме комисия  това, не се хилядната порта прави кавалерия Кажимеж Кенеди фантастичен отнасреща  11е9 януари 7 1гоколо .  100персийскиБележки,   майорглавнокомандващФорбах Ингрия .,  за мощпървите ѝ,   групипод отбраналинейни .  Българското съставКампанията4“ .03 0TV -Sa ebcliiurcu
# 751162/751162 [==============================] - 590s 786us/sample - loss: 3.5147 - val_loss: 4.2234
# Epoch 9/10
# 751040/751162 [============================>.] - ETA: 0s - loss: 3.4588- ETA: 0s - loss:В началото на Първата Световна Война война ()и
#  R 1първи aоттегля  Биткаблизо  допри  6Сирия1 първии   поначин хърватисеверозападно , не  ималоза Великата дома   сиармияръководствотоно  .  БългарскатаАсенармия  е  отхвърленаза  най- муграданасила , където е брат му V тронавътрешно- и дн .противопоставят .морска,  накоето  усилиясе  оттегляв ,северно   ото нищов,  за  Гърциязамянана  за  пазарисес  е  подписанонапримирие  по .решениенанасочени  секции .
# грузинскиХоландската  са  начинизтеглянетона2    августбунтовницитеумират4.
#    редицакорупциятаконфликтиот
# 751162/751162 [==============================] - 568s 756us/sample - loss: 3.4588 - val_loss: 4.2255
# Epoch 10/10
# 751104/751162 [============================>.] - ETA: 0s - loss: 3.4020В началото на Първата Световна Война е на обявена заради война.
#  подкрепата
# е
# 2за   най-мартдобърси нападение   конференцияЗаслужилв на   британскиЮжнаx и   Кореявшаблона .   ––111 2889 4г.  конфликтавойски отновоПриучастват   окупацията ввинагина   се кралствоюг се  от СъветскатаНАТО в  през декември1 11999година
#  4 на
# Гърция мирен . испанскотона  позициячийто .новСлед   за тазибиткане.    успявасамонасъстава    .Отѝ8началото ,  век8 натези   Франциясе надСъветския   съюз чиитообачеграници  се  опитванаводене  да
# 751162/751162 [==============================] - 568s 757us/sample - loss: 3.4020 - val_loss: 4.2325

# %%
tf.train.latest_checkpoint("./cbow")
# Out:
# './cbow\\ckpt_10'
